# %%
import requests
from datetime import datetime
import smtplib
from email.message import EmailMessage
from datetime import datetime, timedelta
import pandas as pd
# Function to retrieve weather forecast
def get_weather_forecast():
    # Set your API token obtained from the token request page
    api_token = "UNmHisiIutbbSdsvQZGTdZhzzEYiMtuV"

    # Set the base URL for the NOAA API
    #base_url = "https://api.weather.gov/points/40.655253,-105.308434"
    base_url = "https://api.weather.gov/points/40.655253,-105.308434"

    # Set the headers with the API token
    headers = {"token": api_token}

    # Send the HTTP GET request to retrieve the data
    response = requests.get(base_url, headers=headers)

    # Check the response status code
    if response.status_code == 200:
        # Extract the forecast URL from the response
        data = response.json()
        forecast_url = data["properties"]["forecast"]

        # Send a new HTTP GET request to retrieve the forecast data
        forecast_response = requests.get(forecast_url, headers=headers)

        # Check the forecast response status code
        if forecast_response.status_code == 200:
            # Extract the data from the forecast response
            forecast_data = forecast_response.json()
            return forecast_data
        else:
            return None
    else:
        return None

# Function to send email
def send_email(subject, content, to_emails):
    # Ensure to_emails is a list
    if isinstance(to_emails, str):
        to_emails = [to_emails]

    # Email settings
    SMTP_SERVER = 'smtp-mail.outlook.com'
    SMTP_PORT = 587
    EMAIL_ADDRESS = 'magstadt.shayne@hotmail.com'
    EMAIL_PASSWORD = 'Kirby123$'

    msg = EmailMessage()
    msg.set_content(content)
    msg['Subject'] = subject
    msg['From'] = EMAIL_ADDRESS
    msg['To'] = ', '.join(to_emails)

    with smtplib.SMTP(SMTP_SERVER, SMTP_PORT) as smtp:
        smtp.starttls()  # Upgrade the connection to encrypted SSL/TLS
        smtp.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
        smtp.send_message(msg)

# if __name__ == '__main__':
#     # Get today's date
#     today = datetime.now().date()

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for forecast
#         periods = [
#             {"label": "Today", "index": 0},
#             {"label": "Tonight", "index": 1},
#             {"label": "Tomorrow", "index": 2},
#             {"label": "Tomorrow Night", "index": 3}
#         ]

#         # Prepare weather information
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
#             if label == "Today":
#                 # Check if it's still today
#                 if today != start_time.date():
#                     label = "Later Today"
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"

#         # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
#         recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")
        
# weather_info


# if __name__ == '__main__':
#     # Get today's date
#     today = datetime.now().date()

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for forecast (including the next five days)
#         periods = [
#             {"label": "Today", "index": 0},
#             {"label": "Tonight", "index": 1},
#         ]
        
#         from datetime import timedelta
        
#         # Add the next five days to the periods list (only considering day forecasts)
#         for i in range(2, 14, 2):
#             periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
#         # Prepare weather information
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"

#                 # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
#         recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")


# if __name__ == '__main__':
#     # Get today's date in the desired format
#     today_str = datetime.now().strftime("%Y-%m-%d")

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for Today and Tonight
#         periods = [{"label": "Today", "index": 0}, {"label": "Tonight", "index": 1}]
        
#         # Initialize list to hold weather data for appending to CSV
#         weather_data_to_append = []
        
#         # Prepare weather information and data to append
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            
#             # Append to the weather information string
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"
            
#             # Append data to the list for CSV if the period is for today's date
#             if start_date == today_str:
#                 weather_data_to_append.append([start_date, label, detailed_forecast])
        
#         # Convert list to DataFrame
#         new_data_df = pd.DataFrame(weather_data_to_append, columns=['Date', 'Period', 'Forecast'])
        
#         # CSV file path
#         #csv_file_path = "C:\\Users\\magst\\Desktop\\testingweatherarchive2.csv" # Change this to your actual file path
#         csv_file_path ="C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
#         # Read in existing CSV file, or create it if it doesn't exist
#         try:
#             existing_data_df = pd.read_csv(csv_file_path)
#             # If today's date is already present, remove it before appending the new data
#             existing_data_df = existing_data_df[existing_data_df['Date'] != today_str]
#         except FileNotFoundError:
#             existing_data_df = pd.DataFrame(columns=['Date', 'Period', 'Forecast'])
        
#         # Append new data
#         updated_data_df = pd.concat([existing_data_df, new_data_df], ignore_index=True)
        
#         # Save the appended data back to CSV
#         updated_data_df.to_csv(csv_file_path, index=False)
        
#         # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue'
#         recipients = ['magstadt.shayne@hotmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")

# %%
if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Get the weather forecast
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        from datetime import timedelta
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        # Prepare weather information
        weather_info = ""
        for period in periods:
            index = period["index"]
            label = period["label"]
            start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
            start_date = start_time.strftime("%Y-%m-%d")
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_info += f"{label} ({start_date}):\n"
            weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
            weather_info += detailed_forecast + "\n\n"

               # Convert list to DataFrame
        new_data_df = pd.DataFrame(weather_data_to_append, columns=['Date', 'Period', 'Forecast'])
        
        # CSV file path
        #csv_file_path = "C:\\Users\\magst\\Desktop\\testingweatherarchive2.csv" # Change this to your actual file path
        csv_file_path ="C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        # Read in existing CSV file, or create it if it doesn't exist
        try:
            existing_data_df = pd.read_csv(csv_file_path)
            # If today's date is already present, remove it before appending the new data
            existing_data_df = existing_data_df[existing_data_df['Date'] != today_str]
        except FileNotFoundError:
            existing_data_df = pd.DataFrame(columns=['Date', 'Period', 'Forecast'])
        
        # Append new data
        updated_data_df = pd.concat([existing_data_df, new_data_df], ignore_index=True)
        
        # Save the appended data back to CSV
        updated_data_df.to_csv(csv_file_path, index=False)     
            
            
                # Send email with weather information
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather report sent successfully!

# %%
from datetime import datetime, timedelta
import pandas as pd

# def get_weather_forecast():
#     # Placeholder for actual weather forecast fetching logic.
#     pass

# def send_email(subject, body, recipients):
#     # Placeholder for actual email sending logic.
#     pass

if __name__ == '__main__':
    today = datetime.now().date()
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        weather_info = ""
        weather_data_to_append = []  # Initialize the list to hold weather data for appending to CSV

        for period in periods:
            index = period["index"]
            label = period["label"]
            start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
            start_date = start_time.strftime("%Y-%m-%d")
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_info += f"{label} ({start_date}):\n"
            weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
            weather_info += detailed_forecast + "\n\n"

            # Append data to the list for CSV
            weather_data_to_append.append([start_date, label, detailed_forecast])
        
        # Convert list to DataFrame
        new_data_df = pd.DataFrame(weather_data_to_append, columns=['Date', 'Period', 'Forecast'])
        
        csv_file_path ="C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        
        try:
            existing_data_df = pd.read_csv(csv_file_path)
            existing_data_df = existing_data_df[existing_data_df['Date'] != today.strftime("%Y-%m-%d")]
        except FileNotFoundError:
            existing_data_df = pd.DataFrame(columns=['Date', 'Period', 'Forecast'])
        
        # Append new data
        updated_data_df = pd.concat([existing_data_df, new_data_df], ignore_index=True)
        
        # Save the appended data back to CSV
        updated_data_df.to_csv(csv_file_path, index=False)     
            
        # Send email with weather information
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather report sent successfully!

# %%
from datetime import datetime, timedelta
import pandas as pd

# def get_weather_forecast():
#     # Placeholder for actual weather forecast fetching logic.
#     pass

# def send_email(subject, body, recipients):
#     # Placeholder for actual email sending logic.
#     pass

if __name__ == '__main__':
    today = datetime.now().date()
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
            # Assuming indexes for subsequent days
            {"label": "Day1", "index": 2},
            {"label": "Day2", "index": 3},
            {"label": "Day3", "index": 4},
            {"label": "Day4", "index": 5},
            {"label": "Day5", "index": 6},
            # Add more days if needed
        ]
        
        weather_info = ""
        weather_data_dict = {}

        for period in periods:
            index = period["index"]
            label = period["label"]
            period_forecast_data = forecast_data["properties"]["periods"][index]
            start_time = datetime.fromisoformat(period_forecast_data["startTime"])
            start_date = start_time.strftime("%Y-%m-%d")
            detailed_forecast = period_forecast_data["detailedForecast"]

            weather_info += f"{label} ({start_date}):\n"
            weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
            weather_info += detailed_forecast + "\n\n"

            # Create or update the dictionary for the specific date
            if start_date not in weather_data_dict:
                weather_data_dict[start_date] = {}
            weather_data_dict[start_date][label] = detailed_forecast
        
        # Create DataFrame from dictionary
        weather_data_df = pd.DataFrame.from_dict(weather_data_dict, orient='index')
        
        # Ensure the DataFrame columns are in the correct order
        ordered_columns = [period['label'] for period in periods]
        weather_data_df = weather_data_df[ordered_columns]

        csv_file_path ="C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        
        try:
            existing_data_df = pd.read_csv(csv_file_path, index_col='Date')
            # Combine the new data with the existing, ensuring no duplicates
            updated_data_df = existing_data_df.combine_first(weather_data_df)
        except FileNotFoundError:
            updated_data_df = weather_data_df
        
        # Save the appended data back to CSV
        updated_data_df.to_csv(csv_file_path)
        
        # Send email with weather information
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather report sent successfully!

# %%
from datetime import datetime, timedelta
import pandas as pd



if __name__ == '__main__':
    today = datetime.now().date()
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Initialize a dictionary to hold weather data with the date as the key
        weather_data = {}

        for forecast in forecast_data["properties"]["periods"]:
            forecast_date = datetime.fromisoformat(forecast["startTime"]).date()
            period_name = forecast["name"]  # E.g., "Today", "Tonight", "Day1", etc.

            # Initialize the dictionary for a new date
            if forecast_date not in weather_data:
                weather_data[forecast_date] = {}

            # Assign the forecast to the correct period name
            weather_data[forecast_date][period_name] = forecast["detailedForecast"]
        
        # Convert dictionary to a DataFrame
        weather_df = pd.DataFrame.from_dict(weather_data, orient='index')

        # Reset index to turn the dates into a column
        weather_df.reset_index(inplace=True)
        weather_df.rename(columns={'index': 'Date'}, inplace=True)

        # Save to CSV, merging with existing data if necessary
        csv_file_path = "C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        try:
            existing_df = pd.read_csv(csv_file_path)
            # Merge while avoiding duplication of rows
            updated_df = pd.merge(existing_df, weather_df, on='Date', how='outer', suffixes=('', '_y')).fillna('')
            updated_df.to_csv(csv_file_path, index=False)
        except (FileNotFoundError, pd.errors.EmptyDataError):
            # If the file does not exist or is empty, write the new data
            weather_df.to_csv(csv_file_path, index=False)
        
        # Send email with weather information
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com']#, 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather report sent successfully!

# %%
if __name__ == '__main__':
    today = datetime.now().date()
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Create an empty dictionary to hold the forecast for today
        today_forecast = {'Date': today.strftime('%Y-%m-%d')}

        # Go through the forecast data and collect information for the current date
        for period in forecast_data["properties"]["periods"]:
            period_name = period["name"]
            start_time = datetime.fromisoformat(period["startTime"]).date()

            # Check if the period corresponds to today's date
            if start_time == today:
                today_forecast[period_name] = period["detailedForecast"]

        # Convert the dictionary to a DataFrame
        today_forecast_df = pd.DataFrame([today_forecast])

        # Save the DataFrame to a CSV file
        #csv_file_path = "WeatherForecast_Today.csv"  # Update this to your actual file path
        
        csv_file_path = "C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"

        today_forecast_df.to_csv(csv_file_path, index=False)
        
        # Send an email with today's weather information
        weather_info = '\n'.join([f"{k}: {v}" for k, v in today_forecast.items()])
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather report sent successfully!

# %%
from datetime import datetime, timedelta
import pandas as pd


if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Get the weather forecast
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Create an empty dictionary to hold the forecast for today
        today_forecast = {'Date': today.strftime('%Y-%m-%d')}
        periods = [{"label": "Today", "index": 0}, {"label": "Tonight", "index": 1}]
        weather_data_to_append = []

        # Go through the forecast data and collect information for the current date
        for period in forecast_data["properties"]["periods"]:
            start_time = datetime.fromisoformat(period["startTime"]).date()
            period_name = period["name"]
            detailed_forecast = period["detailedForecast"]
            
            index = period["index"]
            label = period["label"]
            start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
            start_date = start_time.strftime("%Y-%m-%d")
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            
            # Append to the weather information string
            weather_info += f"{label} ({start_date}):\n"
            weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
            weather_info += detailed_forecast + "\n\n"
            
            # Add only the forecast for today and tonight directly with their names
            if start_time == today and (period_name.lower() == "today" or period_name.lower() == "tonight"):
                today_forecast[period_name] = detailed_forecast
            # For other periods, check if the start time is after today and rename them as Day1, Day2, etc.
            elif start_time > today:
                days_difference = (start_time - today).days
                new_period_name = f"Day{days_difference}"
                # Check if the new_period_name already exists, increment the day count if so
                while new_period_name in today_forecast:
                    days_difference += 1
                    new_period_name = f"Day{days_difference}"
                today_forecast[new_period_name] = detailed_forecast

        # Convert the dictionary to a DataFrame
        today_forecast_df = pd.DataFrame([today_forecast])

        # Define the CSV file path
        csv_file_path = "C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"

        # Save the DataFrame to a CSV file
        today_forecast_df.to_csv(csv_file_path, index=False)
        
        # Send an email with today's weather information
        weather_info = '\n'.join([f"{k}: {v}" for k, v in today_forecast.items()])
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 24
#      21 period_name = period["name"]
#      22 detailed_forecast = period["detailedForecast"]
# ---> 24 index = period["index"]
#      25 label = period["label"]
#      26 start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#
# KeyError: 'index'

# %%
if __name__ == '__main__':
    # Get today's date in the desired format
    today_str = datetime.now().strftime("%Y-%m-%d")

    # Get the weather forecast
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for Today and Tonight
        periods = [{"label": "Today", "index": 0}, {"label": "Tonight", "index": 1}]
        
        # Initialize list to hold weather data for appending to CSV
        weather_data_to_append = []
        
        # Prepare weather information and data to append
        weather_info = ""
        for period in periods:
            index = period["index"]
            label = period["label"]
            start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
            start_date = start_time.strftime("%Y-%m-%d")
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            
            # Append to the weather information string
            weather_info += f"{label} ({start_date}):\n"
            weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
            weather_info += detailed_forecast + "\n\n"
            
            # Append data to the list for CSV if the period is for today's date
            if start_date == today_str:
                weather_data_to_append.append([start_date, label, detailed_forecast])
        
        # Convert list to DataFrame
        new_data_df = pd.DataFrame(weather_data_to_append, columns=['Date', 'Period', 'Forecast'])
        
        # CSV file path
        #csv_file_path = "C:\\Users\\magst\\Desktop\\testingweatherarchive2.csv" # Change this to your actual file path
        csv_file_path ="C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        # Read in existing CSV file, or create it if it doesn't exist
        try:
            existing_data_df = pd.read_csv(csv_file_path)
            # If today's date is already present, remove it before appending the new data
            existing_data_df = existing_data_df[existing_data_df['Date'] != today_str]
        except FileNotFoundError:
            existing_data_df = pd.DataFrame(columns=['Date', 'Period', 'Forecast'])
        
        # Append new data
        updated_data_df = pd.concat([existing_data_df, new_data_df], ignore_index=True)
        
        # Save the appended data back to CSV
        updated_data_df.to_csv(csv_file_path, index=False)
        
        # Send email with weather information
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue'
        recipients = ['magstadt.shayne@hotmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[33], line 41
#      39 # Read in existing CSV file, or create it if it doesn't exist
#      40 try:
# ---> 41     existing_data_df = pd.read_csv(csv_file_path)
#      42     # If today's date is already present, remove it before appending the new data
#      43     existing_data_df = existing_data_df[existing_data_df['Date'] != today_str]
#
# File ~\anaconda3\envs\ee\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\ee\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\ee\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\envs\ee\lib\site-packages\pandas\io\parsers\readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\ee\lib\site-packages\pandas\io\parsers\readers.py:1236, in TextFileReader._make_engine(self, f, engine)
#    1233     raise ValueError(msg)
#    1235 try:
# -> 1236     return mapping[engine](f, **self.options)
#    1237 except Exception:
#    1238     if self.handles is not None:
#
# File ~\anaconda3\envs\ee\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File ~\anaconda3\envs\ee\lib\site-packages\pandas\_libs\parsers.pyx:551, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Get the weather forecast
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        from datetime import timedelta
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        # Prepare weather information
        weather_info = ""
        for period in periods:
            index = period["index"]
            label = period["label"]
            start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
            start_date = start_time.strftime("%Y-%m-%d")
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_info += f"{label} ({start_date}):\n"
            weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
            weather_info += detailed_forecast + "\n\n"

                # Send email with weather information
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
        
import csv
from datetime import datetime, timedelta

if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Assume get_weather_forecast() is defined elsewhere and retrieves weather forecast data
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        # Initialize an empty list to store weather data rows
        weather_data = [today.strftime("%Y-%m-%d")]
        
        # Prepare weather information and append to weather_data list
        for period in periods:
            index = period["index"]
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_data.append(detailed_forecast)
        
        # Read the existing CSV and append the new row
        csv_file_path = "C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        with open(csv_file_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(weather_data)
        
        print("Weather forecast data appended to CSV successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather report sent successfully!
# Weather forecast data appended to CSV successfully!

# %%
import csv
from datetime import datetime, timedelta

if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Assume get_weather_forecast() is defined elsewhere and retrieves weather forecast data
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        # Initialize an empty list to store weather data rows
        weather_data = [today.strftime("%Y-%m-%d")]
        
        # Prepare weather information and append to weather_data list
        for period in periods:
            index = period["index"]
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_data.append(detailed_forecast)
        
        # Read the existing CSV and append the new row
        csv_file_path = "C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        with open(csv_file_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(weather_data)
        
        print("Weather forecast data appended to CSV successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather forecast data appended to CSV successfully!

# %%
import requests
from datetime import datetime
import smtplib
from email.message import EmailMessage
from datetime import datetime, timedelta
import pandas as pd
# Function to retrieve weather forecast
def get_weather_forecast():
    # Set your API token obtained from the token request page
    api_token = "UNmHisiIutbbSdsvQZGTdZhzzEYiMtuV"

    # Set the base URL for the NOAA API
    #base_url = "https://api.weather.gov/points/40.655253,-105.308434"
    base_url = "https://api.weather.gov/points/40.655253,-105.308434"

    # Set the headers with the API token
    headers = {"token": api_token}

    # Send the HTTP GET request to retrieve the data
    response = requests.get(base_url, headers=headers)

    # Check the response status code
    if response.status_code == 200:
        # Extract the forecast URL from the response
        data = response.json()
        forecast_url = data["properties"]["forecast"]

        # Send a new HTTP GET request to retrieve the forecast data
        forecast_response = requests.get(forecast_url, headers=headers)

        # Check the forecast response status code
        if forecast_response.status_code == 200:
            # Extract the data from the forecast response
            forecast_data = forecast_response.json()
            return forecast_data
        else:
            return None
    else:
        return None

# Function to send email
def send_email(subject, content, to_emails):
    # Ensure to_emails is a list
    if isinstance(to_emails, str):
        to_emails = [to_emails]

    # Email settings
    SMTP_SERVER = 'smtp-mail.outlook.com'
    SMTP_PORT = 587
    EMAIL_ADDRESS = 'magstadt.shayne@hotmail.com'
    EMAIL_PASSWORD = 'Kirby123$'

    msg = EmailMessage()
    msg.set_content(content)
    msg['Subject'] = subject
    msg['From'] = EMAIL_ADDRESS
    msg['To'] = ', '.join(to_emails)

    with smtplib.SMTP(SMTP_SERVER, SMTP_PORT) as smtp:
        smtp.starttls()  # Upgrade the connection to encrypted SSL/TLS
        smtp.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
        smtp.send_message(msg)

# if __name__ == '__main__':
#     # Get today's date
#     today = datetime.now().date()

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for forecast
#         periods = [
#             {"label": "Today", "index": 0},
#             {"label": "Tonight", "index": 1},
#             {"label": "Tomorrow", "index": 2},
#             {"label": "Tomorrow Night", "index": 3}
#         ]

#         # Prepare weather information
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
#             if label == "Today":
#                 # Check if it's still today
#                 if today != start_time.date():
#                     label = "Later Today"
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"

#         # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
#         recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")
        
# weather_info


# if __name__ == '__main__':
#     # Get today's date
#     today = datetime.now().date()

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for forecast (including the next five days)
#         periods = [
#             {"label": "Today", "index": 0},
#             {"label": "Tonight", "index": 1},
#         ]
        
#         from datetime import timedelta
        
#         # Add the next five days to the periods list (only considering day forecasts)
#         for i in range(2, 14, 2):
#             periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
#         # Prepare weather information
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"

#                 # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
#         recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")


# if __name__ == '__main__':
#     # Get today's date in the desired format
#     today_str = datetime.now().strftime("%Y-%m-%d")

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for Today and Tonight
#         periods = [{"label": "Today", "index": 0}, {"label": "Tonight", "index": 1}]
        
#         # Initialize list to hold weather data for appending to CSV
#         weather_data_to_append = []
        
#         # Prepare weather information and data to append
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            
#             # Append to the weather information string
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"
            
#             # Append data to the list for CSV if the period is for today's date
#             if start_date == today_str:
#                 weather_data_to_append.append([start_date, label, detailed_forecast])
        
#         # Convert list to DataFrame
#         new_data_df = pd.DataFrame(weather_data_to_append, columns=['Date', 'Period', 'Forecast'])
        
#         # CSV file path
#         #csv_file_path = "C:\\Users\\magst\\Desktop\\testingweatherarchive2.csv" # Change this to your actual file path
#         csv_file_path ="C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
#         # Read in existing CSV file, or create it if it doesn't exist
#         try:
#             existing_data_df = pd.read_csv(csv_file_path)
#             # If today's date is already present, remove it before appending the new data
#             existing_data_df = existing_data_df[existing_data_df['Date'] != today_str]
#         except FileNotFoundError:
#             existing_data_df = pd.DataFrame(columns=['Date', 'Period', 'Forecast'])
        
#         # Append new data
#         updated_data_df = pd.concat([existing_data_df, new_data_df], ignore_index=True)
        
#         # Save the appended data back to CSV
#         updated_data_df.to_csv(csv_file_path, index=False)
        
#         # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue'
#         recipients = ['magstadt.shayne@hotmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")

        
        
        
if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Get the weather forecast
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        from datetime import timedelta
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        # Prepare weather information
        weather_info = ""
        for period in periods:
            index = period["index"]
            label = period["label"]
            start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
            start_date = start_time.strftime("%Y-%m-%d")
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_info += f"{label} ({start_date}):\n"
            weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
            weather_info += detailed_forecast + "\n\n"

                # Send email with weather information
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
        
import csv
from datetime import datetime, timedelta

if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Assume get_weather_forecast() is defined elsewhere and retrieves weather forecast data
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        # Initialize an empty list to store weather data rows
        weather_data = [today.strftime("%Y-%m-%d")]
        
        # Prepare weather information and append to weather_data list
        for period in periods:
            index = period["index"]
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_data.append(detailed_forecast)
        
        # Read the existing CSV and append the new row
        csv_file_path = "C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        with open(csv_file_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(weather_data)
        
        print("Weather forecast data appended to CSV successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather report sent successfully!
# Weather forecast data appended to CSV successfully!

# %%
import requests
from datetime import datetime
import smtplib
from email.message import EmailMessage
from datetime import datetime, timedelta
import pandas as pd
# Function to retrieve weather forecast
def get_weather_forecast():
    # Set your API token obtained from the token request page
    api_token = "UNmHisiIutbbSdsvQZGTdZhzzEYiMtuV"

    # Set the base URL for the NOAA API
    #base_url = "https://api.weather.gov/points/40.655253,-105.308434"
    base_url = "https://api.weather.gov/points/40.655253,-105.308434"

    # Set the headers with the API token
    headers = {"token": api_token}

    # Send the HTTP GET request to retrieve the data
    response = requests.get(base_url, headers=headers)

    # Check the response status code
    if response.status_code == 200:
        # Extract the forecast URL from the response
        data = response.json()
        forecast_url = data["properties"]["forecast"]

        # Send a new HTTP GET request to retrieve the forecast data
        forecast_response = requests.get(forecast_url, headers=headers)

        # Check the forecast response status code
        if forecast_response.status_code == 200:
            # Extract the data from the forecast response
            forecast_data = forecast_response.json()
            return forecast_data
        else:
            return None
    else:
        return None

# Function to send email
def send_email(subject, content, to_emails):
    # Ensure to_emails is a list
    if isinstance(to_emails, str):
        to_emails = [to_emails]

    # Email settings
    SMTP_SERVER = 'smtp-mail.outlook.com'
    SMTP_PORT = 587
    EMAIL_ADDRESS = 'magstadt.shayne@hotmail.com'
    EMAIL_PASSWORD = 'Kirby123$'

    msg = EmailMessage()
    msg.set_content(content)
    msg['Subject'] = subject
    msg['From'] = EMAIL_ADDRESS
    msg['To'] = ', '.join(to_emails)

    with smtplib.SMTP(SMTP_SERVER, SMTP_PORT) as smtp:
        smtp.starttls()  # Upgrade the connection to encrypted SSL/TLS
        smtp.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
        smtp.send_message(msg)

# if __name__ == '__main__':
#     # Get today's date
#     today = datetime.now().date()

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for forecast
#         periods = [
#             {"label": "Today", "index": 0},
#             {"label": "Tonight", "index": 1},
#             {"label": "Tomorrow", "index": 2},
#             {"label": "Tomorrow Night", "index": 3}
#         ]

#         # Prepare weather information
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
#             if label == "Today":
#                 # Check if it's still today
#                 if today != start_time.date():
#                     label = "Later Today"
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"

#         # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
#         recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")
        
# weather_info


# if __name__ == '__main__':
#     # Get today's date
#     today = datetime.now().date()

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for forecast (including the next five days)
#         periods = [
#             {"label": "Today", "index": 0},
#             {"label": "Tonight", "index": 1},
#         ]
        
#         from datetime import timedelta
        
#         # Add the next five days to the periods list (only considering day forecasts)
#         for i in range(2, 14, 2):
#             periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
#         # Prepare weather information
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"

#                 # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
#         recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")


# if __name__ == '__main__':
#     # Get today's date in the desired format
#     today_str = datetime.now().strftime("%Y-%m-%d")

#     # Get the weather forecast
#     forecast_data = get_weather_forecast()

#     if forecast_data:
#         # Define periods for Today and Tonight
#         periods = [{"label": "Today", "index": 0}, {"label": "Tonight", "index": 1}]
        
#         # Initialize list to hold weather data for appending to CSV
#         weather_data_to_append = []
        
#         # Prepare weather information and data to append
#         weather_info = ""
#         for period in periods:
#             index = period["index"]
#             label = period["label"]
#             start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
#             start_date = start_time.strftime("%Y-%m-%d")
#             detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            
#             # Append to the weather information string
#             weather_info += f"{label} ({start_date}):\n"
#             weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
#             weather_info += detailed_forecast + "\n\n"
            
#             # Append data to the list for CSV if the period is for today's date
#             if start_date == today_str:
#                 weather_data_to_append.append([start_date, label, detailed_forecast])
        
#         # Convert list to DataFrame
#         new_data_df = pd.DataFrame(weather_data_to_append, columns=['Date', 'Period', 'Forecast'])
        
#         # CSV file path
#         #csv_file_path = "C:\\Users\\magst\\Desktop\\testingweatherarchive2.csv" # Change this to your actual file path
#         csv_file_path ="C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
#         # Read in existing CSV file, or create it if it doesn't exist
#         try:
#             existing_data_df = pd.read_csv(csv_file_path)
#             # If today's date is already present, remove it before appending the new data
#             existing_data_df = existing_data_df[existing_data_df['Date'] != today_str]
#         except FileNotFoundError:
#             existing_data_df = pd.DataFrame(columns=['Date', 'Period', 'Forecast'])
        
#         # Append new data
#         updated_data_df = pd.concat([existing_data_df, new_data_df], ignore_index=True)
        
#         # Save the appended data back to CSV
#         updated_data_df.to_csv(csv_file_path, index=False)
        
#         # Send email with weather information
#         subject = '*!*!* Daily Weather Report *!*!* - Bellvue'
#         recipients = ['magstadt.shayne@hotmail.com']
#         send_email(subject, weather_info, recipients)
#         print("Weather report sent successfully!")
#     else:
#         print("Failed to retrieve weather forecast.")

        
        
        
if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Get the weather forecast
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        from datetime import timedelta
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        # Prepare weather information
        weather_info = ""
        for period in periods:
            index = period["index"]
            label = period["label"]
            start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
            start_date = start_time.strftime("%Y-%m-%d")
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_info += f"{label} ({start_date}):\n"
            weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
            weather_info += detailed_forecast + "\n\n"

                # Send email with weather information
        subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
        recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
        send_email(subject, weather_info, recipients)
        print("Weather report sent successfully!")
    else:
        print("Failed to retrieve weather forecast.")
        # Get today's date
        today = datetime.now().date()

        # Get the weather forecast
        forecast_data = get_weather_forecast()

        if forecast_data:
            # Define periods for forecast (including the next five days)
            periods = [
                {"label": "Today", "index": 0},
                {"label": "Tonight", "index": 1},
            ]

            from datetime import timedelta

            # Add the next five days to the periods list (only considering day forecasts)
            for i in range(2, 14, 2):
                periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})

            # Prepare weather information
            weather_info = ""
            for period in periods:
                index = period["index"]
                label = period["label"]
                start_time = datetime.fromisoformat(forecast_data["properties"]["periods"][index]["startTime"])
                start_date = start_time.strftime("%Y-%m-%d")
                detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
                weather_info += f"{label} ({start_date}):\n"
                weather_info += "-" * (len(label) + len(start_date) + 4) + "\n"
                weather_info += detailed_forecast + "\n\n"

                    # Send email with weather information
            subject = '*!*!* Daily Weather Report *!*!* - Bellvue, CO'
            recipients = ['magstadt.shayne@hotmail.com', 'lucy.corro@gmail.com']
            send_email(subject, weather_info, recipients)
            print("Weather report sent successfully attempt 2!")
        
import csv
from datetime import datetime, timedelta

if __name__ == '__main__':
    # Get today's date
    today = datetime.now().date()

    # Assume get_weather_forecast() is defined elsewhere and retrieves weather forecast data
    forecast_data = get_weather_forecast()

    if forecast_data:
        # Define periods for forecast (including the next five days)
        periods = [
            {"label": "Today", "index": 0},
            {"label": "Tonight", "index": 1},
        ]
        
        # Add the next five days to the periods list (only considering day forecasts)
        for i in range(2, 14, 2):
            periods.append({"label": (today + timedelta(days=i//2)).strftime("%A"), "index": i})
        
        # Initialize an empty list to store weather data rows
        weather_data = [today.strftime("%Y-%m-%d")]
        
        # Prepare weather information and append to weather_data list
        for period in periods:
            index = period["index"]
            detailed_forecast = forecast_data["properties"]["periods"][index]["detailedForecast"]
            weather_data.append(detailed_forecast)
        
        # Read the existing CSV and append the new row
        csv_file_path = "C:\\Users\\admin-magstadt\\Desktop\\WeatherArchive\\WeatherArchive_BellvueCO.csv"
        with open(csv_file_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(weather_data)
        
        print("Weather forecast data appended to CSV successfully!")
    else:
        print("Failed to retrieve weather forecast.")
# Out:
# Weather report sent successfully!
# Weather forecast data appended to CSV successfully!
